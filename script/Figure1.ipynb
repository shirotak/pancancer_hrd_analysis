# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
from scipy import stats
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use('seaborn-white')

# %%
SMALL_SIZE = 7
MEDIUM_SIZE = 8
LARGE_SIZE = 10
BIGGER_SIZE = 12
plt.rc('font', size=LARGE_SIZE)     
plt.rc('axes', titlesize=MEDIUM_SIZE)    
plt.rc('axes', labelsize=MEDIUM_SIZE)    
plt.rc('axes', linewidth=0.5) 
plt.rc('xtick', labelsize=SMALL_SIZE)    
plt.rc('ytick', labelsize=SMALL_SIZE) 
plt.rc('legend', fontsize=MEDIUM_SIZE)    
plt.rc('figure', titlesize=BIGGER_SIZE, dpi=300, figsize=(5,4) )

# %%
path_to_data="../data/"
path_to_results="../results/"

# %% [markdown]
# # Figure 1A

# %%
plt_df=pd.read_csv(path_to_data+"Data_for_Figure1.tsv",sep="\t",index_col=0)
value="HRD_score"
plt_df=plt_df.dropna(subset=[value]).sort_values(by=value,ascending=False)
print(len(plt_df))
columns=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']\
+['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']\
+['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']\
+["BRCA1_methylation"]
# Out:
# 9399

# %%
cols=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1A_1.png",bbox_inches="tight")
# Out:
# gBRCA1_LOH  p=1.53e-36
# gBRCA2_LOH  p=2.53e-24
# gHRR_LOH  p=3.11e-15
# sBRCA1_LOH  p=3.16e-20
# sBRCA2_LOH  p=5.63e-12
# sHRR_LOH  p=2.43e-11

# %%
cols=['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1A_2.png",bbox_inches="tight")
# Out:
# gBRCA1_nonLOH  p=3.73e-01
# gBRCA2_nonLOH  p=3.77e-01
# gHRR_nonLOH  p=4.83e-01
# sBRCA1_nonLOH  p=6.11e-02
# sBRCA2_nonLOH  p=5.78e-08
# sHRR_nonLOH  p=2.28e-10

# %%
cols=['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1A_3.png",bbox_inches="tight")
# Out:
# BRCA2_homdel  p=1.26e-07
# RAD51B_homdel  p=1.39e-08
# nonBRCA_HRR_homdel  p=5.17e-11

# %%
cols=["BRCA1_methylation"]
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1A_4.png",bbox_inches="tight")
# Out:
# BRCA1_methylation  p=2.99e-28

# %%
col="HRD_score"
m=1
fig = plt.figure(figsize=(15,0.5*m))
ax=fig.add_subplot(1,1,1)
ax=sns.heatmap( data=plt_df[[col]].T, cmap="rainbow",xticklabels=0,yticklabels=0, cbar=False,
                   vmin=0,vmax=100)
ax.set_xticks([])
ax.set_yticks([])
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1A_5.png",bbox_inches="tight")

# %%
# calculate p_values 
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
for col in columns[0:15]:
    a=plt_df.loc[ plt_df[col]==1,value].values
    b=plt_df.loc[ plt_df[col]==0 ,value].values
    c=np.mean(a )-np.mean(b)
    _,p=stats.mannwhitneyu(a,b)
    dict_gene_p_diff["p-value"][col]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][col]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1A_p_diff_table.tsv",sep="\t")
table
# Out:
#                      p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1_LOH          1.53e-36            45.01       1       1       1
# gBRCA2_LOH          2.53e-24            35.21       1       1       1
# gHRR_LOH            3.11e-15            21.39       1       1       1
# sBRCA1_LOH          3.16e-20            44.42       1       1       1
# sBRCA2_LOH          5.63e-12            24.31       1       1       1
# sHRR_LOH            2.43e-11            10.11       1       1       1
# gBRCA1_nonLOH       3.73e-01            -3.01       0       0       0
# gBRCA2_nonLOH       3.77e-01             3.18       0       0       0
# gHRR_nonLOH         4.83e-01            -0.42       0       0       0
# sBRCA1_nonLOH       6.11e-02            -3.16       0       0       0
# sBRCA2_nonLOH       5.78e-08            -5.84       1       1       1
# sHRR_nonLOH         2.28e-10            -3.52       1       1       1
# ...

# %%
# LOH vs nonLOH per alteration
gLOH1=plt_df[ plt_df["gBRCA1_LOH"]==1][value].values
gLOH2=plt_df[ plt_df["gBRCA2_LOH"]==1][value].values
gLOH3=plt_df[ plt_df["gHRR_LOH"]==1][value].values
gnonLOH1=plt_df[ plt_df["gBRCA1_nonLOH"]==1][value].values
gnonLOH2=plt_df[ plt_df["gBRCA2_nonLOH"]==1][value].values
gnonLOH3=plt_df[ plt_df["gHRR_nonLOH"]==1][value].values
sLOH1=plt_df[ plt_df["sBRCA1_LOH"]==1][value].values
sLOH2=plt_df[ plt_df["sBRCA2_LOH"]==1][value].values
sLOH3=plt_df[ plt_df["sHRR_LOH"]==1][value].values
snonLOH1=plt_df[ plt_df["sBRCA1_nonLOH"]==1][value].values
snonLOH2=plt_df[ plt_df["sBRCA2_nonLOH"]==1][value].values
snonLOH3=plt_df[ plt_df["sHRR_nonLOH"]==1][value].values

data_comp=[gLOH1,gnonLOH1,gLOH2,gnonLOH2,gLOH3,gnonLOH3,sLOH1,snonLOH1,sLOH2,snonLOH2,sLOH3,snonLOH3]

# %%
fig = plt.figure(figsize=(3.5,1.5))
ax = fig.add_subplot(1,1,1)
bp=ax.boxplot(data_comp, showfliers=False,patch_artist=True, 
              widths=0.75)
colors=[(1,0,0,0.7),(0,0,1,0.7)]*6
# box face color
for b, c in zip(bp['boxes'], colors):
    b.set(color=c, linewidth=0.5) 
    b.set_facecolor(c)
    b.set_edgecolor("k")
# median line
for b, c in zip(bp['medians'], colors):
    b.set(color="k",linewidth=0.5)
for b, c in zip(bp['whiskers'], colors*2):
    b.set(linewidth=0.5)
# caps
for b, c in zip(bp['caps'], colors*2):
    b.set( linewidth=0.5)

ax.set_xlabel('')
ax.set_ylabel("HRD score",fontsize=MEDIUM_SIZE)
labels=["g$BRCA1$","g$BRCA2$","gHRR","s$BRCA1$","s$BRCA2$","sHRR"]
ax.set_xticks([1.5,3.5,5.5,7.5,9.5,11.5])
ax.set_xticklabels(labels)
ax.spines['top'].set_visible(False)
ax.spines['right' ].set_visible(False)

plt.savefig(path_to_results+"Figure1A_6.png",bbox_inches="tight")

# %%
# vs Others for each alteration
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
labels=["gBRCA1","gBRCA2","gHRR","sBRCA1","sBRCA2","sHRR"]
for label,loh,nonloh in zip(labels,[gLOH1,gLOH2,gLOH3,sLOH1,sLOH2,sLOH3],[gnonLOH1,gnonLOH2,gnonLOH3,snonLOH1,snonLOH2,snonLOH3]):
    _,p=stats.mannwhitneyu(loh,nonloh)
    c=np.nanmean(loh)-np.nanmean(nonloh)
    dict_gene_p_diff["p-value"][label]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][label]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1C_p_diff_table.tsv",sep="\t")
table
# Out:
#          p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1  7.72e-11            47.73       1       1       1
# gBRCA2  4.15e-08            31.86       1       1       1
# gHRR    7.16e-12            21.67       1       1       1
# sBRCA1  3.00e-13            47.40       1       1       1
# sBRCA2  7.36e-12            29.99       1       1       1
# sHRR    7.03e-15            13.32       1       1       1

# %% [markdown]
# # Figure 1B

# %%
plt_df=pd.read_csv(path_to_data+"Data_for_Figure1.tsv",sep="\t",index_col=0)

# %%
value="MSK_Sig3_ratio"
plt_df=plt_df.dropna(subset=[value]).sort_values(by=value,ascending=False)
print(len(plt_df))
columns=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']\
+['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']\
+['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']\
+["BRCA1_methylation"]
# Out:
# 9610

# %%
cols=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_1.png",bbox_inches="tight")
# Out:
# gBRCA1_LOH  p=2.05e-29
# gBRCA2_LOH  p=4.02e-21
# gHRR_LOH  p=9.72e-03
# sBRCA1_LOH  p=2.21e-13
# sBRCA2_LOH  p=2.26e-07
# sHRR_LOH  p=1.07e-01

# %%
cols=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_1.png",bbox_inches="tight")
# Out:
# gBRCA1_LOH  p=2.05e-29
# gBRCA2_LOH  p=4.02e-21
# gHRR_LOH  p=9.72e-03
# sBRCA1_LOH  p=2.21e-13
# sBRCA2_LOH  p=2.26e-07
# sHRR_LOH  p=1.07e-01

# %%
cols=['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_2.png",bbox_inches="tight")
# Out:
# gBRCA1_nonLOH  p=3.60e-01
# gBRCA2_nonLOH  p=9.96e-03
# gHRR_nonLOH  p=6.63e-02
# sBRCA1_nonLOH  p=2.88e-11
# sBRCA2_nonLOH  p=2.58e-24
# sHRR_nonLOH  p=2.22e-49

# %%
cols=['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_2.png",bbox_inches="tight")
# Out:
# gBRCA1_nonLOH  p=3.60e-01
# gBRCA2_nonLOH  p=9.96e-03
# gHRR_nonLOH  p=6.63e-02
# sBRCA1_nonLOH  p=2.88e-11
# sBRCA2_nonLOH  p=2.58e-24
# sHRR_nonLOH  p=2.22e-49

# %%
cols=['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_3.png",bbox_inches="tight")
# Out:
# BRCA2_homdel  p=3.66e-08
# RAD51B_homdel  p=3.52e-05
# nonBRCA_HRR_homdel  p=3.42e-05

# %%
cols=["BRCA1_methylation"]
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_4.png",bbox_inches="tight")
# Out:
# BRCA1_methylation  p=6.93e-22

# %%
col="MSK_Sig3_ratio"
m=1
fig = plt.figure(figsize=(15,0.5*m))
ax=fig.add_subplot(1,1,1)
ax=sns.heatmap( data=plt_df[[col]].T, cmap="rainbow",xticklabels=0,yticklabels=0, cbar=False,
                   vmin=0,vmax=0.5)
ax.set_xticks([])
ax.set_yticks([])
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1B_5.png",bbox_inches="tight")

# %%
# vs Others for each alteration
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
for col in columns[0:15]:
    a=plt_df.loc[ plt_df[col]==1,value].values
    b=plt_df.loc[ plt_df[col]==0 ,value].values
    c=np.mean(a )-np.mean(b)
    _,p=stats.mannwhitneyu(a,b)
    dict_gene_p_diff["p-value"][col]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][col]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1B_p_diff_table.tsv",sep="\t")
table
# Out:
#                      p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1_LOH          2.05e-29             0.28       1       1       1
# gBRCA2_LOH          4.02e-21             0.25       1       1       1
# gHRR_LOH            9.72e-03             0.06       1       0       0
# sBRCA1_LOH          2.21e-13             0.24       1       1       1
# sBRCA2_LOH          2.26e-07             0.16       1       1       1
# sHRR_LOH            1.07e-01             0.01       0       0       0
# gBRCA1_nonLOH       3.60e-01            -0.02       0       0       0
# gBRCA2_nonLOH       9.96e-03             0.07       1       0       0
# gHRR_nonLOH         6.63e-02            -0.01       0       0       0
# sBRCA1_nonLOH       2.88e-11            -0.06       1       1       1
# sBRCA2_nonLOH       2.58e-24            -0.06       1       1       1
# sHRR_nonLOH         2.22e-49            -0.04       1       1       1
# ...

# %%
# LOH vs nonLOH per alteration
gLOH1=plt_df[ plt_df["gBRCA1_LOH"]==1][value].values
gLOH2=plt_df[ plt_df["gBRCA2_LOH"]==1][value].values
gLOH3=plt_df[ plt_df["gHRR_LOH"]==1][value].values
gnonLOH1=plt_df[ plt_df["gBRCA1_nonLOH"]==1][value].values
gnonLOH2=plt_df[ plt_df["gBRCA2_nonLOH"]==1][value].values
gnonLOH3=plt_df[ plt_df["gHRR_nonLOH"]==1][value].values
sLOH1=plt_df[ plt_df["sBRCA1_LOH"]==1][value].values
sLOH2=plt_df[ plt_df["sBRCA2_LOH"]==1][value].values
sLOH3=plt_df[ plt_df["sHRR_LOH"]==1][value].values
snonLOH1=plt_df[ plt_df["sBRCA1_nonLOH"]==1][value].values
snonLOH2=plt_df[ plt_df["sBRCA2_nonLOH"]==1][value].values
snonLOH3=plt_df[ plt_df["sHRR_nonLOH"]==1][value].values

data_comp=[gLOH1,gnonLOH1,gLOH2,gnonLOH2,gLOH3,gnonLOH3,sLOH1,snonLOH1,sLOH2,snonLOH2,sLOH3,snonLOH3]

# %%
fig = plt.figure(figsize=(3.5,1.5))
ax = fig.add_subplot(1,1,1)
bp=ax.boxplot(data_comp, showfliers=False,patch_artist=True, 
              widths=0.75)
colors=[(1,0,0,0.7),(0,0,1,0.7)]*6
# box face color
for b, c in zip(bp['boxes'], colors):
    b.set(color=c, linewidth=0.5) 
    b.set_facecolor(c)
    b.set_edgecolor("k")
# median line
for b, c in zip(bp['medians'], colors):
    b.set(color="k",linewidth=0.5)
for b, c in zip(bp['whiskers'], colors*2):
    b.set(linewidth=0.5)
# caps
for b, c in zip(bp['caps'], colors*2):
    b.set( linewidth=0.5)

ax.set_xlabel('')
ax.set_ylabel("Sig3 ratio",fontsize=MEDIUM_SIZE)
labels=["g$BRCA1$","g$BRCA2$","gHRR","s$BRCA1$","s$BRCA2$","sHRR"]
ax.set_xticks([1.5,3.5,5.5,7.5,9.5,11.5])
ax.set_xticklabels(labels)
ax.spines['top'].set_visible(False)
ax.spines['right' ].set_visible(False)


plt.savefig(path_to_results+"Figure1B_6.png",bbox_inches="tight")

# %%
# vs Others for each alteration
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
labels=["gBRCA1","gBRCA2","gHRR","sBRCA1","sBRCA2","sHRR"]
for label,loh,nonloh in zip(labels,[gLOH1,gLOH2,gLOH3,sLOH1,sLOH2,sLOH3],[gnonLOH1,gnonLOH2,gnonLOH3,snonLOH1,snonLOH2,snonLOH3]):
    _,p=stats.mannwhitneyu(loh,nonloh)
    c=np.nanmean(loh)-np.nanmean(nonloh)
    dict_gene_p_diff["p-value"][label]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][label]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1C_p_diff_table.tsv",sep="\t")
table
# Out:
#          p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1  1.41e-09             0.29       1       1       1
# gBRCA2  3.46e-05             0.18       1       1       0
# gHRR    4.25e-03             0.08       1       0       0
# sBRCA1  4.56e-12             0.30       1       1       1
# sBRCA2  1.18e-11             0.21       1       1       1
# sHRR    1.66e-05             0.05       1       1       0

# %% [markdown]
# # Figure 1C

# %%
plt_df=pd.read_csv(path_to_data+"Data_for_Figure1.tsv",sep="\t",index_col=0)

# %%
value="TMB_log10"
plt_df=plt_df.dropna(subset=[value]).sort_values(by=value,ascending=False)
print(len(plt_df))
columns=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']\
+['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']\
+['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']\
+["BRCA1_methylation"]\
+["MSI_annotation"+	"sPOL_mut"]
# Out:
# 9672

# %%
cols=['gBRCA1_LOH', 'gBRCA2_LOH', 'gHRR_LOH', 'sBRCA1_LOH', 'sBRCA2_LOH','sHRR_LOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_1.png",bbox_inches="tight")
# Out:
# gBRCA1_LOH  p=6.16e-04
# gBRCA2_LOH  p=3.45e-04
# gHRR_LOH  p=1.99e-01
# sBRCA1_LOH  p=1.96e-03
# sBRCA2_LOH  p=4.44e-06
# sHRR_LOH  p=4.32e-07

# %%
cols=['gBRCA1_nonLOH', 'gBRCA2_nonLOH', 'gHRR_nonLOH', 'sBRCA1_nonLOH','sBRCA2_nonLOH', 'sHRR_nonLOH']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value], plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_2.png",bbox_inches="tight")
# Out:
# gBRCA1_nonLOH  p=1.42e-01
# gBRCA2_nonLOH  p=3.34e-01
# gHRR_nonLOH  p=4.68e-01
# sBRCA1_nonLOH  p=4.91e-20
# sBRCA2_nonLOH  p=3.71e-45
# sHRR_nonLOH  p=5.80e-162

# %%
cols=['BRCA2_homdel', 'RAD51B_homdel', 'nonBRCA_HRR_homdel']
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_3.png",bbox_inches="tight")
# Out:
# BRCA2_homdel  p=1.77e-01
# RAD51B_homdel  p=2.69e-04
# nonBRCA_HRR_homdel  p=7.46e-04

# %%
cols=["BRCA1_methylation"]
N=plt_df.shape[0]
m=len(cols)

fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_4.png",bbox_inches="tight")
# Out:
# BRCA1_methylation  p=4.53e-01

# %%
cols=["MSI_annotation","sPOL_mut"]
N=plt_df.shape[0]
m=len(cols)
fig = plt.figure(figsize=(15,0.5*m))
for i,col in enumerate(cols):
    ax=fig.add_subplot(m,1,i+1)
    for j in range(N):
        if plt_df[col][j]==1:
            r=patches.Rectangle(xy=(j/N,0),width=1/N,height=1,color="k")
            ax.add_patch(r)
    ax.set_xticks([])
    ax.set_yticks([])
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2.5)
    
    # Man-Whitney test
    a,b=plt_df[plt_df[col]==1][value],plt_df[plt_df[col]!=1][value]
    _,p=stats.mannwhitneyu(a,b)
    print(col, " p={:.2e}".format(p) )
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_5.png",bbox_inches="tight")
# Out:
# MSI_annotation  p=2.40e-152
# sPOL_mut  p=1.06e-41

# %%
col="TMB_log10"
m=1
fig = plt.figure(figsize=(15,0.5*m))
ax=fig.add_subplot(1,1,1)
ax=sns.heatmap( data=plt_df[[col]].T, cmap="rainbow",xticklabels=0,yticklabels=0, cbar=False,
                   vmin=0,vmax=4.5)
ax.set_xticks([])
ax.set_yticks([])
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2.5)
        
plt.subplots_adjust(hspace=0)

plt.savefig(path_to_results+"Figure1C_6.png",bbox_inches="tight")

# %%
# vs Others for each alteration
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
for col in columns[0:15]:
    a=plt_df.loc[ plt_df[col]==1,value].values
    b=plt_df.loc[ plt_df[col]==0 ,value].values
    c=np.mean(a )-np.mean(b)
    _,p=stats.mannwhitneyu(a,b)
    dict_gene_p_diff["p-value"][col]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][col]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1C_p_diff_table.tsv",sep="\t")
table
# Out:
#                       p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1_LOH           6.16e-04             0.13       1       0       0
# gBRCA2_LOH           3.45e-04             0.16       1       0       0
# gHRR_LOH             1.99e-01             0.04       0       0       0
# sBRCA1_LOH           1.96e-03             0.20       1       0       0
# sBRCA2_LOH           4.44e-06             0.38       1       1       0
# sHRR_LOH             4.32e-07             0.29       1       1       1
# gBRCA1_nonLOH        1.42e-01            -0.18       0       0       0
# gBRCA2_nonLOH        3.34e-01            -0.07       0       0       0
# gHRR_nonLOH          4.68e-01             0.03       0       0       0
# sBRCA1_nonLOH        4.91e-20             1.10       1       1       1
# sBRCA2_nonLOH        3.71e-45             1.22       1       1       1
# sHRR_nonLOH         5.80e-162             0.90       1       1       1
# ...

# %%
# LOH vs nonLOH per alteration
gLOH1=plt_df[ plt_df["gBRCA1_LOH"]==1][value].values
gLOH2=plt_df[ plt_df["gBRCA2_LOH"]==1][value].values
gLOH3=plt_df[ plt_df["gHRR_LOH"]==1][value].values
gnonLOH1=plt_df[ plt_df["gBRCA1_nonLOH"]==1][value].values
gnonLOH2=plt_df[ plt_df["gBRCA2_nonLOH"]==1][value].values
gnonLOH3=plt_df[ plt_df["gHRR_nonLOH"]==1][value].values
sLOH1=plt_df[ plt_df["sBRCA1_LOH"]==1][value].values
sLOH2=plt_df[ plt_df["sBRCA2_LOH"]==1][value].values
sLOH3=plt_df[ plt_df["sHRR_LOH"]==1][value].values
snonLOH1=plt_df[ plt_df["sBRCA1_nonLOH"]==1][value].values
snonLOH2=plt_df[ plt_df["sBRCA2_nonLOH"]==1][value].values
snonLOH3=plt_df[ plt_df["sHRR_nonLOH"]==1][value].values

data_comp=[gLOH1,gnonLOH1,gLOH2,gnonLOH2,gLOH3,gnonLOH3,sLOH1,snonLOH1,sLOH2,snonLOH2,sLOH3,snonLOH3]

# %%
fig = plt.figure(figsize=(3.5,1.5))
ax = fig.add_subplot(1,1,1)
bp=ax.boxplot(data_comp, showfliers=False,patch_artist=True, 
              widths=0.75)
colors=[(1,0,0,0.7),(0,0,1,0.7)]*6
# box face color
for b, c in zip(bp['boxes'], colors):
    b.set(color=c, linewidth=0.5) 
    b.set_facecolor(c)
    b.set_edgecolor("k")
# median line
for b, c in zip(bp['medians'], colors):
    b.set(color="k",linewidth=0.5)
for b, c in zip(bp['whiskers'], colors*2):
    b.set(linewidth=0.5)
# caps
for b, c in zip(bp['caps'], colors*2):
    b.set( linewidth=0.5)

ax.set_xlabel('')
ax.set_ylabel("TMB log10",fontsize=MEDIUM_SIZE)
labels=["g$BRCA1$","g$BRCA2$","gHRR","s$BRCA1$","s$BRCA2$","sHRR"]
ax.set_xticks([1.5,3.5,5.5,7.5,9.5,11.5])
ax.set_xticklabels(labels)
ax.spines['top'].set_visible(False)
ax.spines['right' ].set_visible(False)

plt.savefig(path_to_results+"Figure1C_7.png",bbox_inches="tight")

# %%
# vs Others for each alteration
dict_gene_p_diff={ "p-value":{},"mean difference":{} }
labels=["gBRCA1","gBRCA2","gHRR","sBRCA1","sBRCA2","sHRR"]
for label,loh,nonloh in zip(labels,[gLOH1,gLOH2,gLOH3,sLOH1,sLOH2,sLOH3],[gnonLOH1,gnonLOH2,gnonLOH3,snonLOH1,snonLOH2,snonLOH3]):
    _,p=stats.mannwhitneyu(loh,nonloh)
    c=np.nanmean(loh)-np.nanmean(nonloh)
    dict_gene_p_diff["p-value"][label]="{:.2e}".format(p)
    dict_gene_p_diff["mean difference"][label]=np.round(c,2)

table=pd.DataFrame.from_dict(dict_gene_p_diff)
table["p<0.01"]=( np.array(table["p-value"],dtype=float)<0.01).astype(int)
table["p<1e-4"]=( np.array(table["p-value"],dtype=float)<0.0001).astype(int)
table["p<1e-6"]=( np.array(table["p-value"],dtype=float)<0.000001).astype(int)
table.to_csv(path_to_results+"Figure1C_p_diff_table.tsv",sep="\t")
table
# Out:
#          p-value  mean difference  p<0.01  p<1e-4  p<1e-6
# gBRCA1  1.68e-02             0.31       0       0       0
# gBRCA2  1.42e-02             0.23       0       0       0
# gHRR    2.37e-01             0.02       0       0       0
# sBRCA1  2.16e-08            -0.90       1       1       1
# sBRCA2  3.72e-08            -0.83       1       1       1
# sHRR    2.18e-14            -0.56       1       1       1
